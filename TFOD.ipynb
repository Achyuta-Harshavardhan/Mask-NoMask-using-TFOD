# %%
# %tensorflow_version 1.x

# %%
import os
import tensorflow as tf

# %%
os.chdir("/content/drive/MyDrive/Object_detection/tfod/models/research")
os.getcwd()
# Out:
# '/content/drive/MyDrive/Object_detection/tfod/models/research'

# %%
# !pip install tf_slim

# %%
# !python train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/ssdlite_mobilenet_v2_coco.config
# Out:
# Streaming output truncated to the last 5000 lines.
# I1217 14:27:28.240998 139727431677824 learning.py:512] global step 147557: loss = 1.7621 (0.638 sec/step)
# INFO:tensorflow:global step 147558: loss = 1.3463 (0.557 sec/step)
# I1217 14:27:28.800009 139727431677824 learning.py:512] global step 147558: loss = 1.3463 (0.557 sec/step)
# INFO:tensorflow:global step 147559: loss = 1.3310 (0.549 sec/step)
# I1217 14:27:29.350937 139727431677824 learning.py:512] global step 147559: loss = 1.3310 (0.549 sec/step)
# INFO:tensorflow:global step 147560: loss = 0.9773 (0.572 sec/step)
# I1217 14:27:29.924499 139727431677824 learning.py:512] global step 147560: loss = 0.9773 (0.572 sec/step)
# INFO:tensorflow:global step 147561: loss = 1.1907 (0.574 sec/step)
# I1217 14:27:30.499803 139727431677824 learning.py:512] global step 147561: loss = 1.1907 (0.574 sec/step)
# INFO:tensorflow:global step 147562: loss = 1.4071 (0.585 sec/step)
# ...

# %%
# !python export_inference_graph.py --input_type=image_tensor --pipeline_config_path=training/ssdlite_mobilenet_v2_coco.config --trained_checkpoint_prefix=training/model.ckpt-150000 --output_directory=saved_model
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W1219 12:27:14.169163 140462054369152 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tf_slim/layers/layers.py:1089: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1219 12:27:16.212325 140462054369152 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1219 12:27:16.293424 140462054369152 convolutional_box_predictor.py:156] depth of additional conv before box predictor: 0
# ...

# %%
# !python Object_detection_webcam.py
# Out:
# [ WARN:0] global /io/opencv/modules/videoio/src/cap_v4l.cpp (802) open VIDEOIO ERROR: V4L: can't open camera by index 0
# [ WARN:0] global /io/opencv/modules/videoio/src/cap_v4l.cpp (802) open VIDEOIO ERROR: V4L: can't open camera by index 0
# 2020-12-19 13:00:43.270948: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-12-19 13:00:43.273431: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-12-19 13:00:43.273978: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-12-19 13:00:43.274296: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...
